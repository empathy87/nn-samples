# %%
import pandas as pd

# %%
x = pd.read_csv('Inputs.txt', header=None, delimiter=r"\s+").values
y = pd.read_csv('Targets.txt', header=None, delimiter=r"\s+").values

# %%
# Out:
# array([[0.27278093, 1.11503618, 0.26872878, 1.94149085, 0.1920474 ,
#         2.19126423, 3.93276449, 0.02429386, 0.67489342, 0.63043873,
#         0.01131333, 1.03862355, 0.01725277, 0.19054851, 0.48376027,
#         1.5490099 , 1.93873816, 0.00577742, 0.0227394 , 0.03476953,
#         2.47958318, 0.41404081, 1.21618542, 1.00061919],
#        [0.26872878, 1.94149085, 0.27278093, 1.11503618, 2.47958318,
#         0.41404081, 1.21618542, 1.00061919, 1.93873816, 0.00577742,
#         0.0227394 , 0.03476953, 0.01725277, 0.19054851, 0.48376027,
#         1.5490099 , 0.67489342, 0.63043873, 0.01131333, 1.03862355,
#         0.1920474 , 2.19126423, 3.93276449, 0.02429386],
#        [1.06789547, 1.79565673, 0.80332339, 1.8332744 , 0.00870843,
#         0.8282541 , 0.00643521, 0.01760661, 0.39491666, 0.12709077,
#         0.90799843, 0.03118472, 0.03982347, 0.3451399 , 4.60120909,
#         0.76834035, 0.71214772, 0.90053093, 0.40188272, 1.84517914,
# ...
