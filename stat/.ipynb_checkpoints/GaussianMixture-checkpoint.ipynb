# %%
import numpy as np
from numpy.random import randint
from matplotlib import pyplot as plt
from scipy.stats import multivariate_normal as mn
import matplotlib
from numpy.linalg import inv
# %matplotlib inline

# %%
I = np.array([[1, 0], [0, 1]])
blue_mean_rv = mn([1, 0], I)
red_mean_rv = mn([0, 1], I)
blue_rv = [mn(blue_mean_rv.rvs(), I/5) for _ in range(10)]
red_rv = [mn(red_mean_rv.rvs(), I/5) for _ in range(10)]
rvs = {'blue': blue_rv, 'red': red_rv}

# %%
def classifier(model, x):
    return model(x) > 0.5

# %%
def bayes(x):
    pr, pb = 0, 0
    for r in rvs['blue']:
        pb += r.pdf(x)
    for r in rvs['red']:
        pr += r.pdf(x)
    return pr/(pb+pr)

# %%
X, Y = np.zeros(shape=(10200, 2)), np.zeros(shape=(10200, 1))
for i in range(10200):
    X[i] = rvs[('blue','red')[i%2]][randint(10)].rvs()
    Y[i] = i%2
X_train, X_test = X[:200,:], X[200:,:]
Y_train, Y_test = Y[:200,:], Y[200:,:]

# %%
x_min = np.amin(X, axis=0)
x_max = np.amax(X, axis=0)

# %%
x1_grid, x2_grid = np.meshgrid(np.linspace(x_min[0], x_max[0], 100),
                               np.linspace(x_min[1], x_max[1], 100))

def fill_grid(model):
    y_grid = np.zeros(shape=x1_grid.shape)
    for i in range(100):
        for j in range(100):
            y_grid[i, j] = classifier(model, [x1_grid[i,j], x2_grid[i,j]])    
    return y_grid

# %%
def plot_decision_boundary(model):
    y_grid = fill_grid(model)
    fig, ax1 = plt.subplots(figsize=(6, 6), dpi=110)
    cmap = matplotlib.colors.ListedColormap(['#4A81BF', '#C3514E'])
    ax1.contour(x1_grid, x2_grid, y_grid, colors='black', linewidths=1)
    ax1.scatter(x1_grid, x2_grid, c=y_grid, s=0.1, cmap=cmap)
    ax1.scatter(X_train[:,0], X_train[:,1], c=Y_train[:,0], cmap=cmap)
    ax1.set_xlim(x_min[0], x_max[0])
    ax1.set_ylim(x_min[1], x_max[1])
    
plot_decision_boundary(bayes)

# %%
def hat(model, X):
    Y_hat = np.zeros(shape=(X.shape[0], 1))
    for i in range(X.shape[0]):
        Y_hat[i] = model(X[i])
    return Y_hat

# %%
def mse(model, X, Y):
    Y_hat = hat(model, X)
    return ((Y - Y_hat).T.dot(Y - Y_hat)/X.shape[0])[0,0]

# %%
mse(bayes, X_test, Y_test)
# Out:
# 0.14496750971480762

# %%
X, Y = np.ones(shape=(200, 3)), Y_train
X[:,1:] = X_train

# %%
b = inv((X.T.dot(X))).dot(X.T).dot(Y).squeeze()
def linear(x):
    return b.dot(np.array([1, x[0], x[1]]))

# %%
plot_decision_boundary(linear)

# %%
mse(linear, X_test, Y_test)
# Out:
# array([[0.176932]])

# %%
k = 4
def k_means(x):
    return np.mean(Y_train[((X_train[:,0]-x[0])**2 + (X_train[:,1]-x[1])**2).argsort()[:k]])

# %%
plot_decision_boundary(k_means)

# %%
for k in range(1, 40):
    print(mse(k_means, X_train, Y_train), mse(k_means, X_test, Y_test),)
# Out:
# 0.0 0.296
# 0.07125 0.22
# 0.10611111111111109 0.19255555555555587
# 0.1225 0.180825
# 0.1272 0.1746239999999998
# 0.13291666666666666 0.16952777777777764
# 0.13693877551020409 0.16653469387755052
# 0.136328125 0.164759375
# 0.13709876543209878 0.16263333333333335
# 0.14175 0.16076900000000013
# 0.14111570247933883 0.16094132231404934
# 0.13826388888888888 0.16114166666666666
# 0.14183431952662723 0.1609254437869824
# 0.1436734693877551 0.16057040816326507
# 0.1442222222222222 0.16040311111111133
# 0.14794921875 0.160076171875
# 0.14877162629757787 0.1604145328719726
# 0.14959876543209877 0.1606475308641979
# 0.14986149584487532 0.16108531855955688
# 0.1507125 0.16129499999999974
# 0.15136054421768705 0.16184875283446684
# 0.1524896694214876 0.16241735537190047
# 0.15493383742911152 0.1633064272211722
# 0.15688368055555557 0.1634475694444442
# 0.15803200000000003 0.16406239999999958
# 0.15898668639053254 0.16461553254437866
# 0.16057613168724277 0.1650256515775037
# 0.16189413265306118 0.16540765306122415
# 0.16214030915576688 0.16565326991676593
# 0.1625777777777778 0.166092888888889
# 0.16312174817898023 0.16658938605619092
# 0.165224609375 0.16693369140625
# 0.16587235996326907 0.1675855831037649
# 0.16702854671280282 0.1681240484429071
# 0.16631020408163263 0.16880514285714282
# 0.16800925925925927 0.16948796296296284
# 0.16955441928414905 0.17008451424397342
# 0.1710387811634349 0.17068337950138515
# 0.17183760683760677 0.1715983563445103
